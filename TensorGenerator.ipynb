# %%
from clang.cindex import Config

# Set the path to libclang.dll
Config.set_library_path(r"C:\Users\wille\Documents\Projects\AI Code Buster\LLVM\bin")

# %%
import os
from clang.cindex import Index, CursorKind

TARGET_FUNCTION_NAME = "main"  # Replace with the desired function name
TARGET_FILENAME = "grade_calculator.cpp"  # Replace with the desired filename
OUTPUT_DIR = "extracted_functions"

def extract_function(node, target_function_name):
    """Recursively find and return the target function definition."""
    if node.kind == CursorKind.FUNCTION_DECL and node.spelling == target_function_name:
        start = node.extent.start
        end = node.extent.end
        with open(node.translation_unit.spelling, "r", encoding="utf-8", errors="ignore") as f:
            lines = f.readlines()
            # Extract the exact lines corresponding to the function
            function_code = "".join(lines[start.line - 1:end.line])
            return function_code
    for child in node.get_children():
        result = extract_function(child, target_function_name)
        if result:
            return result
    return None

def process_file(file_path, sample_name, output_dir, target_function_name):
    """Parse a file and extract the target function."""
    index = Index.create()
    translation_unit = index.parse(file_path)
    function_code = extract_function(translation_unit.cursor, target_function_name)
    if function_code:
        # Save the function code to the output directory
        os.makedirs(output_dir, exist_ok=True)
        output_file = os.path.join(output_dir, f"{sample_name}_{target_function_name}.cpp")
        with open(output_file, "w", encoding="utf-8") as out_f:
            out_f.write(function_code)
        print(f"Extracted {target_function_name} from {file_path}")
    else:
        print(f"{target_function_name} not found in {file_path}")

def process_dataset(dataset_dir, target_filename, output_dir, target_function_name):
    """Process the dataset directory and extract functions."""
    for root, dirs, files in os.walk(dataset_dir):
        if target_filename in files:
            sample_name = os.path.basename(root)  # Get the folder name (e.g., sample1)
            file_path = os.path.join(root, target_filename)
            process_file(file_path, sample_name, output_dir, target_function_name)

if __name__ == "__main__":
    DATASET_DIR = "./HUMAN"  # Replace with the actual path
    process_dataset(DATASET_DIR, TARGET_FILENAME, OUTPUT_DIR, TARGET_FUNCTION_NAME)
    print(f"Functions extracted to {OUTPUT_DIR}")
# Out:
# Extracted main from ./HUMAN\HWGradeCalculator_F2024\submission_262105732\grade_calculator.cpp
# Extracted main from ./HUMAN\HWGradeCalculator_F2024\submission_262115957\grade_calculator.cpp
# Extracted main from ./HUMAN\HWGradeCalculator_F2024\submission_262122910\grade_calculator.cpp
# Extracted main from ./HUMAN\HWGradeCalculator_F2024\submission_262141092\grade_calculator.cpp
# Extracted main from ./HUMAN\HWGradeCalculator_F2024\submission_262144309\grade_calculator.cpp
# Extracted main from ./HUMAN\HWGradeCalculator_F2024\submission_262189906\grade_calculator.cpp
# Extracted main from ./HUMAN\HWGradeCalculator_F2024\submission_262199591\grade_calculator.cpp
# Extracted main from ./HUMAN\HWGradeCalculator_F2024\submission_262215782\grade_calculator.cpp
# Extracted main from ./HUMAN\HWGradeCalculator_F2024\submission_262226542\grade_calculator.cpp
# Extracted main from ./HUMAN\HWGradeCalculator_F2024\submission_262232666\grade_calculator.cpp
# ...
